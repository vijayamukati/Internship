# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split 
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OrdinalEncoder
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
train_data = pd.read_excel(r"E:\capstoneprojects\Datasets\flight_price_prediction\Data_Train.xlsx")
train_data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
test_data = pd.read_excel(r"E:\capstoneprojects\Datasets\flight_price_prediction\Test_set.xlsx")
test_data
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# 2     DEL → BOM → COK    19:15  19:00 22 May  23h 45m      1 stop
# 3     DEL → BOM → COK    08:00         21:00      13h      1 stop
# 4           BLR → DEL    23:55  02:45 25 Jun   2h 50m    non-stop
# ...               ...      ...           ...      ...         ...
# 2666  CCU → DEL → BLR    20:30  20:25 07 Jun  23h 55m      1 stop
# 2667        CCU → BLR    14:20         16:55   2h 35m    non-stop
# 2668  DEL → BOM → COK    21:50  04:25 07 Mar   6h 35m      1 stop
# 2669  DEL → BOM → COK    04:00         19:15  15h 15m      1 stop
# 2670  DEL → BOM → COK    04:55         19:15  14h 20m      1 stop
#
#                   Additional_Info
# 0                         No info
# 1                         No info
# 2     In-flight meal not included
# 3                         No info
# 4                         No info
# ...                           ...
# 2666                      No info
# 2667                      No info
# 2668                      No info
# 2669                      No info
# 2670                      No info
#
# [2671 rows x 10 columns]

# %%
df = pd.concat([test_data, train_data])

# %%
df
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0            Jet Airways       6/06/2019     Delhi      Cochin
# 1                 IndiGo      12/05/2019   Kolkata    Banglore
# 2            Jet Airways      21/05/2019     Delhi      Cochin
# 3      Multiple carriers      21/05/2019     Delhi      Cochin
# 4               Air Asia      24/06/2019  Banglore       Delhi
# ...                  ...             ...       ...         ...
# 10678           Air Asia       9/04/2019   Kolkata    Banglore
# 10679          Air India      27/04/2019   Kolkata    Banglore
# 10680        Jet Airways      27/04/2019  Banglore       Delhi
# 10681            Vistara      01/03/2019  Banglore   New Delhi
# 10682          Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0            DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1            CCU → MAA → BLR    06:20         10:20       4h      1 stop
# 2            DEL → BOM → COK    19:15  19:00 22 May  23h 45m      1 stop
# 3            DEL → BOM → COK    08:00         21:00      13h      1 stop
# 4                  BLR → DEL    23:55  02:45 25 Jun   2h 50m    non-stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#                    Additional_Info    Price
# 0                          No info      NaN
# 1                          No info      NaN
# 2      In-flight meal not included      NaN
# 3                          No info      NaN
# 4                          No info      NaN
# ...                            ...      ...
# 10678                      No info   4107.0
# 10679                      No info   4145.0
# 10680                      No info   7229.0
# 10681                      No info  12648.0
# 10682                      No info  11753.0
#
# [13354 rows x 11 columns]

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.shape
# Out:
# (13354, 11)

# %%
df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 2673

# %%
df['Route']= df['Route'].fillna(df['Route'].mode()[0])
df['Total_Stops']= df['Total_Stops'].fillna(df['Total_Stops'].mode()[0])
df['Price']= df['Price'].fillna(df['Price'].mean())

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
plt.figure(figsize=(30,8),facecolor='lightgreen')
sns.countplot(x='Airline', data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='count'>

# %%
##jet airways are more in no.as compared to other flights....other flights which are more frequent other than jet airways are 
#Indigo  and Air india.....

# %%
plt.figure(figsize=(30,8),facecolor='lightgreen')
sns.violinplot(x='Airline', y='Price', data=df,hue='Source')
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Price'>

# %%
#Air india ,Jet airways,spice jet,indigo,vistara MAINLY strts from delhi,kolkata,banglore,mumbai,chennai
#carrier flights only originate from delhi

# %%
plt.figure(figsize=(30,8),facecolor='lightgreen')
sns.stripplot(x='Airline', y='Price', data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Price'>

# %%
#jet airways have price between 3000 to 20,000 mostly except some exceptional cases
#air india also has price varying between 3000 to 20,000

# %%
plt.figure(figsize=(30,8),facecolor='lightgreen')
sns.stripplot(x='Airline', y='Price',hue='Total_Stops' ,data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Price'>

# %%
#most jet airways flights have mostly one stops ...
#air india has mostly two stops..
#multiple carriers flight have only one stop...
# some flights of jet airways , indigo,,spicejet,vistara,air india are non stops .....
#very few flights have 3 stops ....
#mostly no flights have 4 stops

# %%
plt.figure(figsize=(30,8),facecolor='lightgreen')
sns.stripplot(x='Airline', y='Price',hue='Source' ,data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Price'>

# %%
plt.figure(figsize=(30,8),facecolor='lightgreen')
sns.stripplot(x='Airline', y='Price',hue='Destination',data=df)
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Price'>

# %%
#many flights have destination hyderabad and new delhi ,cochin,banglore....
##jet airways & air india flights have all major cities as destiation i.e. cochin,banglore,delhi,new delhi,hyderabad,kolkata
#multiple carriers flights only go to cochin

# %%
df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# dtype: object

# %%
df["Journey_day"] = pd.to_datetime(df.Date_of_Journey, format="%d/%m/%Y").dt.day
df["Journey_month"] = pd.to_datetime(df["Date_of_Journey"], format = "%d/%m/%Y").dt.month
df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#          Price  Journey_day  Journey_month
# 0  9087.064121            6              6
# 1  9087.064121           12              5
# 2  9087.064121           21              5
# 3  9087.064121           21              5
# 4  9087.064121           24              6

# %%
# So,as we have converted Date_of_Journey column into integers, Now we can drop this column.

df.drop(["Date_of_Journey"], axis = 1, inplace = True)

# %%
# Departure time
df["Dep_hour"] = pd.to_datetime(df["Dep_Time"]).dt.hour
df["Dep_min"] = pd.to_datetime(df["Dep_Time"]).dt.minute

# Now we can drop Dep_Time,
df.drop(["Dep_Time"], axis = 1, inplace = True)
df.head()
# Out:
#              Airline    Source Destination            Route  Arrival_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  04:25 07 Jun
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR         10:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  19:00 22 May
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK         21:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL  02:45 25 Jun
#
#   Duration Total_Stops              Additional_Info        Price  Journey_day  \
# 0  10h 55m      1 stop                      No info  9087.064121            6
# 1       4h      1 stop                      No info  9087.064121           12
# 2  23h 45m      1 stop  In-flight meal not included  9087.064121           21
# 3      13h      1 stop                      No info  9087.064121           21
# 4   2h 50m    non-stop                      No info  9087.064121           24
#
#    Journey_month  Dep_hour  Dep_min
# 0              6        17       30
# 1              5         6       20
# 2              5        19       15
# 3              5         8        0
# 4              6        23       55

# %%
# Arrival time 

df["Arrival_hour"] = pd.to_datetime(df.Arrival_Time).dt.hour
df["Arrival_min"] = pd.to_datetime(df.Arrival_Time).dt.minute

# Now we can drop Arrival_Time ,
df.drop(["Arrival_Time"], axis = 1, inplace = True)
df.head()
# Out:
#              Airline    Source Destination            Route Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2h 50m
#
#   Total_Stops              Additional_Info        Price  Journey_day  \
# 0      1 stop                      No info  9087.064121            6
# 1      1 stop                      No info  9087.064121           12
# 2      1 stop  In-flight meal not included  9087.064121           21
# 3      1 stop                      No info  9087.064121           21
# 4    non-stop                      No info  9087.064121           24
#
#    Journey_month  Dep_hour  Dep_min  Arrival_hour  Arrival_min
# 0              6        17       30             4           25
# 1              5         6       20            10           20
# 2              5        19       15            19            0
# 3              5         8        0            21            0
# 4              6        23       55             2           45

# %%
# Assigning and converting Duration column into list
duration = list(df["Duration"])

for i in range(len(duration)):
    if len(duration[i].split()) != 2:   
        if "h" in duration[i]:
            duration[i] = duration[i].strip() + " 0m"   
        else:
            duration[i] = "0h " + duration[i]           

duration_hours = []
duration_mins = []
for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = "h")[0]))   
    duration_mins.append(int(duration[i].split(sep = "m")[0].split()[-1]))

# %%
# Adding duration_hours and duration_mins list to df dataframe

df["Duration_hours"] = duration_hours
df["Duration_mins"] = duration_mins
df.drop(["Duration"], axis = 1, inplace = True)
df.head()
# Out:
#              Airline    Source Destination            Route Total_Stops  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR      1 stop
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      1 stop
# 4           Air Asia  Banglore       Delhi        BLR → DEL    non-stop
#
#                Additional_Info        Price  Journey_day  Journey_month  \
# 0                      No info  9087.064121            6              6
# 1                      No info  9087.064121           12              5
# 2  In-flight meal not included  9087.064121           21              5
# 3                      No info  9087.064121           21              5
# 4                      No info  9087.064121           24              6
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min  Duration_hours  Duration_mins
# 0        17       30             4           25              10             55
# 1         6       20            10           20               4              0
# 2        19       15            19            0              23             45
# 3         8        0            21            0              13              0
# 4        23       55             2           45               2             50

# %%
enc=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#        Airline  Source  Destination  Route  Total_Stops  Additional_Info  \
# 0          4.0     2.0          1.0  108.0          0.0              8.0
# 1          3.0     3.0          0.0   94.0          0.0              8.0
# 2          4.0     2.0          1.0  108.0          0.0              5.0
# 3          6.0     2.0          1.0  108.0          0.0              8.0
# 4          0.0     0.0          2.0   18.0          4.0              8.0
# ...        ...     ...          ...    ...          ...              ...
# 10678      0.0     3.0          0.0   67.0          4.0              8.0
# 10679      1.0     3.0          0.0   67.0          4.0              8.0
# 10680      4.0     0.0          2.0   18.0          4.0              8.0
# 10681     10.0     0.0          5.0   18.0          4.0              8.0
# 10682      1.0     2.0          1.0  112.0          1.0              8.0
#
#               Price  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0       9087.064121            6              6        17       30
# 1       9087.064121           12              5         6       20
# 2       9087.064121           21              5        19       15
# 3       9087.064121           21              5         8        0
# 4       9087.064121           24              6        23       55
# ...             ...          ...            ...       ...      ...
# 10678   4107.000000            9              4        19       55
# 10679   4145.000000           27              4        20       45
# 10680   7229.000000           27              4         8       20
# 10681  12648.000000            1              3        11       30
# 10682  11753.000000            9              5        10       55
#
#        Arrival_hour  Arrival_min  Duration_hours  Duration_mins
# 0                 4           25              10             55
# 1                10           20               4              0
# 2                19            0              23             45
# 3                21            0              13              0
# 4                 2           45               2             50
# ...             ...          ...             ...            ...
# 10678            22           25               2             30
# 10679            23           20               2             35
# 10680            11           20               3              0
# 10681            14           10               2             40
# 10682            19           15               8             20
#
# [13354 rows x 15 columns]

# %%
df
# Out:
#        Airline  Source  Destination  Route  Total_Stops  Additional_Info  \
# 0          4.0     2.0          1.0  108.0          0.0              8.0
# 1          3.0     3.0          0.0   94.0          0.0              8.0
# 2          4.0     2.0          1.0  108.0          0.0              5.0
# 3          6.0     2.0          1.0  108.0          0.0              8.0
# 4          0.0     0.0          2.0   18.0          4.0              8.0
# ...        ...     ...          ...    ...          ...              ...
# 10678      0.0     3.0          0.0   67.0          4.0              8.0
# 10679      1.0     3.0          0.0   67.0          4.0              8.0
# 10680      4.0     0.0          2.0   18.0          4.0              8.0
# 10681     10.0     0.0          5.0   18.0          4.0              8.0
# 10682      1.0     2.0          1.0  112.0          1.0              8.0
#
#               Price  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0       9087.064121            6              6        17       30
# 1       9087.064121           12              5         6       20
# 2       9087.064121           21              5        19       15
# 3       9087.064121           21              5         8        0
# 4       9087.064121           24              6        23       55
# ...             ...          ...            ...       ...      ...
# 10678   4107.000000            9              4        19       55
# 10679   4145.000000           27              4        20       45
# 10680   7229.000000           27              4         8       20
# 10681  12648.000000            1              3        11       30
# 10682  11753.000000            9              5        10       55
#
#        Arrival_hour  Arrival_min  Duration_hours  Duration_mins
# 0                 4           25              10             55
# 1                10           20               4              0
# 2                19            0              23             45
# 3                21            0              13              0
# 4                 2           45               2             50
# ...             ...          ...             ...            ...
# 10678            22           25               2             30
# 10679            23           20               2             35
# 10680            11           20               3              0
# 10681            14           10               2             40
# 10682            19           15               8             20
#
# [13354 rows x 15 columns]

# %%
df.skew()
# Out:
# Airline            0.720924
# Source            -0.424151
# Destination        1.247893
# Route             -0.521448
# Total_Stops        0.639737
# Additional_Info   -1.784752
# Price              2.026457
# Journey_day        0.135142
# Journey_month     -0.390684
# Dep_hour           0.109087
# Dep_min            0.159397
# Arrival_hour      -0.384591
# Arrival_min        0.111711
# Duration_hours     0.857425
# Duration_mins     -0.093531
# dtype: float64

# %%
y = df['Price']
X = df.drop(columns=['Price'])

# %%
np.abs(3)
# Out:
# 3

# %%
np.abs(-3)
# Out:
# 3

# %%
from scipy.stats import zscore
(np.abs(zscore(X))<3).all()
# Out:
# Airline             True
# Source              True
# Destination         True
# Route               True
# Total_Stops         True
# Additional_Info    False
# Journey_day         True
# Journey_month       True
# Dep_hour            True
# Dep_min             True
# Arrival_hour        True
# Arrival_min         True
# Duration_hours     False
# Duration_mins       True
# dtype: bool

# %%
#Data scaling Z=(X-mean)/std

scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_scaled.shape[1]
# Out:
# 14

# %%
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#          vif         Features
# 0   1.053715          Airline
# 1   1.629738           Source
# 2   2.007249      Destination
# 3   1.704629            Route
# 4   1.933686      Total_Stops
# 5   1.077257  Additional_Info
# 6   1.021331      Journey_day
# 7   1.225953    Journey_month
# 8   1.034613         Dep_hour
# 9   1.037254          Dep_min
# 10  1.048871     Arrival_hour
# 11  1.119142      Arrival_min
# 12  1.656496   Duration_hours
# 13  1.122139    Duration_mins

# %%
rf = RandomForestRegressor()
for i in range(0,100):
    X_train,X_test,y_train,y_test =train_test_split(X_scaled,y,test_size=0.2,random_state=i)
    rf.fit(X_train,y_train)
    pred_train = rf.predict(X_train)
    pred_test= rf.predict(X_test)
    print(f"At random state{i},the training accuracy is:-{r2_score(y_train,pred_train)}")
    print(f"At random state{i},the testing accuracy is:-{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state0,the training accuracy is:-0.9430448681973592
# At random state0,the testing accuracy is:-0.6761709294155097
#
#
# At random state1,the training accuracy is:-0.945320973827469
# At random state1,the testing accuracy is:-0.658519913672073
#
#
# At random state2,the training accuracy is:-0.9425593492472325
# At random state2,the testing accuracy is:-0.6726873874404368
#
#
# At random state3,the training accuracy is:-0.944085145473124
# At random state3,the testing accuracy is:-0.6434595643359395
#
#
# At random state4,the training accuracy is:-0.9403928939355046
# At random state4,the testing accuracy is:-0.7180552581422008
#
#
# At random state5,the training accuracy is:-0.9457947921122052
# At random state5,the testing accuracy is:-0.641704853362612
#
#
# At random state6,the training accuracy is:-0.9460874123352983
# At random state6,the testing accuracy is:-0.60938563306444
#
#
# At random state7,the training accuracy is:-0.9424928521868339
# At random state7,the testing accuracy is:-0.7024415018476867
#
#
# At random state8,the training accuracy is:-0.9473269024650817
# At random state8,the testing accuracy is:-0.5759637678459523
#
#
# At random state9,the training accuracy is:-0.9454809003687042
# At random state9,the testing accuracy is:-0.6543553251889149
#
#
# At random state10,the training accuracy is:-0.9428252462713411
# At random state10,the testing accuracy is:-0.6575613368352059
#
#
# At random state11,the training accuracy is:-0.943708509059976
# At random state11,the testing accuracy is:-0.6589259430654923
#
#
# At random state12,the training accuracy is:-0.9438637592361566
# At random state12,the testing accuracy is:-0.6477393164038023
#
#
# At random state13,the training accuracy is:-0.9468802918811354
# At random state13,the testing accuracy is:-0.6307792522126769
#
#
# At random state14,the training accuracy is:-0.9448723027300187
# At random state14,the testing accuracy is:-0.6662084137629688
#
#
# At random state15,the training accuracy is:-0.9441313351207643
# At random state15,the testing accuracy is:-0.6527774023842431
#
#
# At random state16,the training accuracy is:-0.9427352070686471
# At random state16,the testing accuracy is:-0.6838455851594305
#
#
# At random state17,the training accuracy is:-0.942365609652713
# At random state17,the testing accuracy is:-0.6690984408248197
#
#
# At random state18,the training accuracy is:-0.9419253012677601
# At random state18,the testing accuracy is:-0.6922958031531017
#
#
# At random state19,the training accuracy is:-0.943474869740298
# At random state19,the testing accuracy is:-0.6733825082100555
#
#
# At random state20,the training accuracy is:-0.9463473239237804
# At random state20,the testing accuracy is:-0.5721266897138912
#
#
# At random state21,the training accuracy is:-0.9466991861350306
# At random state21,the testing accuracy is:-0.5877324718560013
#
#
# At random state22,the training accuracy is:-0.9475467482592267
# At random state22,the testing accuracy is:-0.56627159508633

# %%
#so as we can interpret random state 87 is giving best train and test accuracy,so we train our model at random state 87:

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=87)

# %%
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
rf.score(X_train,y_train)
y_pred=rf.predict(X_test)
rfs=r2_score(y_test,y_pred)
print('R2 score:',rfs*100)

rfscore=cross_val_score(rf,X,y,cv=5)
rfc=rfscore.mean()
print('cross val score:',rfc*100)

# %%
y_pred=rf.predict(X_test)
y_train.head()

# %%
#Adjusted R2 score
rf.score(X_train,y_train)

# %%
rf.score(X_test,y_test)

# %%
#lets plot and visualize
y_pred=rf.predict(X_test)
y_pred

# %%
plt.scatter(y_test,y_pred,color='r')
plt.xlabel='actual PRICE'
plt.ylabel='Predicted PRICE'
plt.title='Actual vs model predicted '
plt.show()

# %%
print('MAE:', mean_absolute_error(y_test, y_pred))
print('MSE:', mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
dt.score(X_train,y_train)
y_pred=dt.predict(X_test)
dtr=r2_score(y_test,y_pred)
print('R2 score:',dtr*100)

dtscore=cross_val_score(dt,X,y,cv=5)
dtr=dtscore.mean()
print('cross val score:',dtr*100)

# %%
print('MAE:', mean_absolute_error(y_test, y_pred))
print('MSE:', mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
model = ExtraTreesRegressor()
model.fit(X_train,y_train)
model.score(X_train,y_train)
y_pred=model.predict(X_test)
modelr=r2_score(y_test,y_pred)
print('R2 score:',modelr*100)
modelscore=cross_val_score(model,X,y,cv=5)
modelr=modelscore.mean()
print('cross val score:',modelr*100)

# %%
print('MAE:', mean_absolute_error(y_test, y_pred))
print('MSE:', mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
import xgboost as xgb
from xgboost import XGBRegressor
xg=XGBRegressor()

xg.fit(X_train,y_train)
xg.score(X_train,y_train)
y_pred=xg.predict(X_test)
xg_score=r2_score(y_test,y_pred)
print('R2 score:',xg_score*100)
xgscore=cross_val_score(xg,X,y,cv=5)
xgr=dtscore.mean()
print('cross val score:',xgr*100)

# %%
print('MAE:', mean_absolute_error(y_test, y_pred))
print('MSE:', mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor()
ada.fit(X_train,y_train)
ada.score(X_train,y_train)
y_pred=ada.predict(X_test)
ada_score=r2_score(y_test,y_pred)
print('R2 score:',ada_score*100)

adascore=cross_val_score(ada,X,y,cv=5)
adab=adascore.mean()
print('cross val score:',adab*100)

# %%
print('MAE:', mean_absolute_error(y_test, y_pred))
print('MSE:', mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
#as observed the random forest regressor works well with this dataset...so we hypertune parameters of final model RandomForestRegressor using gridsearchCV

parameters ={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2'],'min_samples_split':[2], 
             'min_samples_leaf':[1], 'bootstrap':[True]}

# %%
rf=RandomForestRegressor()
gcv=GridSearchCV(rf,parameters)
gcv.fit(X_train,y_train)
print(gcv.best_params_)

# %%
rf=RandomForestRegressor(criterion='mse',max_features='log2',min_samples_split= 2 ,
             min_samples_leaf=1, bootstrap=True)
rf.fit(X_train,y_train)
rf.score(X_train,y_train)
y_pred=rf.predict(X_test)
rfs=r2_score(y_test,y_pred)
print('R2 score:',rfs*100)
rfscore=cross_val_score(rf,X,y,cv=5)
rfr=rfscore.mean()
print('cross val score:',rfr*100)

# %%
print('MAE:', mean_absolute_error(y_test, y_pred))
print('MSE:',mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
plt.scatter(y_test,y_pred,color='r')
plt.xlabel='actual PRICE'
plt.ylabel='Predicted PRICE'
plt.title='Actual vs model predicted '
plt.show()

# %%
#the best model is RandomForestRegressor with 71% accuracy and 62% cross validation score & 
#MAE: 1541.4725361417416
#MSE: 5051623.706897248
#RMSE: 2247.5817464326515

# %%
#saving the model to local file system
filename='flight price prediction_model.pickle'
pickle.dump(rf,open(filename,'wb'))
